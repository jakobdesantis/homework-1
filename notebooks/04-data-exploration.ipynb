# %% [markdown]
# # Data exploration
#
# ---
#
# Group name: D
#
# ---

# %% [markdown]
# ## Introduction
#
# *This dataset contains nearly 3 million russion troll tweets that have been sent between February 2012 and May 2018.*

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import altair as alt

alt.data_transformers.disable_max_rows()

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Data

# %% [markdown]
# ## Import data

# %%
DATA01 = "https://raw.githubusercontent.com/fivethirtyeight/russian-troll-tweets/master/IRAhandle_tweets_1.csv"
#DATA02 = "https://raw.githubusercontent.com/fivethirtyeight/russian-troll-tweets/master/IRAhandle_tweets_2.csv"
#DATA03 = "https://raw.githubusercontent.com/fivethirtyeight/russian-troll-tweets/master/IRAhandle_tweets_3.csv"
#DATA04 = "https://raw.githubusercontent.com/fivethirtyeight/russian-troll-tweets/master/IRAhandle_tweets_4.csv"
#DATA05 = "https://raw.githubusercontent.com/fivethirtyeight/russian-troll-tweets/master/IRAhandle_tweets_5.csv"
#DATA06 = "https://raw.githubusercontent.com/fivethirtyeight/russian-troll-tweets/master/IRAhandle_tweets_6.csv"
#DATA07 = "https://raw.githubusercontent.com/fivethirtyeight/russian-troll-tweets/master/IRAhandle_tweets_7.csv"
#DATA08 = "https://raw.githubusercontent.com/fivethirtyeight/russian-troll-tweets/master/IRAhandle_tweets_8.csv"
#DATA09 = "https://raw.githubusercontent.com/fivethirtyeight/russian-troll-tweets/master/IRAhandle_tweets_9.csv"
#DATA10 = "https://raw.githubusercontent.com/fivethirtyeight/russian-troll-tweets/master/IRAhandle_tweets_10.csv"
#DATA11 = "https://raw.githubusercontent.com/fivethirtyeight/russian-troll-tweets/master/IRAhandle_tweets_11.csv"
#DATA12 = "https://raw.githubusercontent.com/fivethirtyeight/russian-troll-tweets/master/IRAhandle_tweets_12.csv"
#DATA13 = "https://raw.githubusercontent.com/fivethirtyeight/russian-troll-tweets/master/IRAhandle_tweets_13.csv"

df = pd.read_csv(DATA01)
#df02 = pd.read_csv(DATA02)
#df03 = pd.read_csv(DATA03)
#df04 = pd.read_csv(DATA04)

# %% [markdown]
# ### Data structure

# %%
df
# Out:
#         external_author_id           author  \
# 0       906000000000000000           10_GOP
# 1       906000000000000000           10_GOP
# 2       906000000000000000           10_GOP
# 3       906000000000000000           10_GOP
# 4       906000000000000000           10_GOP
# ...                    ...              ...
# 243886          2497991305  AUSTINLOVESBEER
# 243887          2497991305  AUSTINLOVESBEER
# 243888          2497991305  AUSTINLOVESBEER
# 243889          2497991305  AUSTINLOVESBEER
# 243890          2497991305  AUSTINLOVESBEER
#
#                                                   content         region  \
# 0       "We have a sitting Democrat US Senator on tria...        Unknown
# 1       Marshawn Lynch arrives to game in anti-Trump s...        Unknown
# 2       Daughter of fallen Navy Sailor delivers powerf...        Unknown
# 3       JUST IN: President Trump dedicates Presidents ...        Unknown
# ...

# %% [markdown]
# ### Data corrections

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243891 entries, 0 to 243890
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   external_author_id  243891 non-null  int64
#  1   author              243891 non-null  object
#  2   content             243891 non-null  object
#  3   region              243853 non-null  object
#  4   language            243891 non-null  object
#  5   publish_date        243891 non-null  object
#  6   harvested_date      243891 non-null  object
#  7   following           243891 non-null  int64
#  8   followers           243891 non-null  int64
#  9   updates             243891 non-null  int64
#  10  post_type           154592 non-null  object
#  11  account_type        243891 non-null  object
#  12  retweet             243891 non-null  int64
#  13  account_category    243891 non-null  object
#  14  new_june_2018       243891 non-null  int64
# ...

# %% [markdown]
# Dropping unnecessary columns to reduce data usage

# %%
df = df.drop(df.columns[[6, 11, 13, 14, 15, 16, 17, 18, 19, 20]],axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243891 entries, 0 to 243890
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   external_author_id  243891 non-null  int64
#  1   author              243891 non-null  object
#  2   content             243891 non-null  object
#  3   region              243853 non-null  object
#  4   language            243891 non-null  object
#  5   publish_date        243891 non-null  object
#  6   following           243891 non-null  int64
#  7   followers           243891 non-null  int64
#  8   updates             243891 non-null  int64
#  9   post_type           154592 non-null  object
#  10  retweet             243891 non-null  int64
# dtypes: int64(5), object(6)
# memory usage: 20.5+ MB

# %% [markdown]
# ## Exploratory data analysis
